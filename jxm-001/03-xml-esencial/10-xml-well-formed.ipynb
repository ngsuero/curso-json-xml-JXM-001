// %% [markdown]
// # XML: Documento Bien Formado (Well-Formed)
//
// Antes de validar un XML con reglas avanzadas, debe cumplir las **reglas básicas de sintaxis**.
// Si un XML no está bien formado, ningún parser lo aceptará.

// %% [markdown]
// ## Reglas esenciales de un XML bien formado
//
// ✔ Un **único** elemento raíz
// ✔ Todas las etiquetas deben **cerrar correctamente**
// ✔ Etiquetas **anidadas correctamente** (sin cruzarse)
// ✔ Atributos con **comillas dobles**
// ✔ XML es **sensible a mayúsculas** (Case-sensitive)
//
// Ejemplo correcto:

// %%
const xmlBien = `
<producto>
  <nombre>Teclado</nombre>
  <precio moneda="EUR">89.99</precio>
</producto>`;
console.log(xmlBien);
// Out:
// <producto>
//   <nombre>Teclado</nombre>
//   <precio moneda="EUR">89.99</precio>
// </producto>

// %% [markdown]
// Ejemplo con errores comunes ❌:

// %%
const xmlMal = `
<producto>
  <nombre>Teclado</nombre>
  <precio>89.99</PRECIO>
</producto2>`;
console.log(xmlMal);
// Out:
// <producto>
//   <nombre>Teclado</nombre>
//   <precio>89.99</PRECIO>
// </producto2>

// %% [markdown]
// Error por etiquetas **cruzadas** ❌:

// %%
const xmlCruzado = `<a><b></a></b>`;
console.log(xmlCruzado);
// Out:
// <a><b></a></b>

// %% [markdown]
// ## Declaración XML
// Es opcional pero recomendada para definir versión y codificación:
//
// ```xml
// <?xml version="1.0" encoding="UTF-8"?>
// ```

// %% [markdown]
// ## Atributos bien definidos
// Siempre entre **comillas dobles**:

// %%
const xmlAtributos = `<item categoria="accesorio" disponible="true">Raton</item>`;
console.log(xmlAtributos);
// Out:
// <item categoria="accesorio" disponible="true">Raton</item>

// %% [markdown]
// Atributo sin comillas → inválido ❌

// %%
const xmlAtributosMal = `<item categoria=accesorio>Raton</item>`;
console.log(xmlAtributosMal);
// Out:
// <item categoria=accesorio>Raton</item>

// %% [markdown]
// ## 🧩 Ejercicio
// Reescribe este XML para que sea **bien formado**:
//
// ```xml
// <producto>
//   <nombre>Monitor FullHD
//   <precio moneda=EUR>159.90</precio>
// </producto2>
// ```

// %%
// Tu XML corregido aqui...
const xml = `
<?xml version="1.0" encoding="UTF-8"?>
<producto>
  <nombre>Monitor FullHD</nombre>
  <precio moneda="EUR">159.90</precio>
</producto>`;
console.log(xml);
// Out:
// <?xml version="1.0" encoding="UTF-8"?>
// <producto>
//   <nombre>Monitor FullHD</nombre>
//   <precio moneda="EUR">159.90</precio>
// </producto>

// %% [markdown]
// <details><summary>Solución</summary>
//
// ```xml
// <?xml version="1.0" encoding="UTF-8"?>
// <producto>
//   <nombre>Monitor FullHD</nombre>
//   <precio moneda="EUR">159.90</precio>
// </producto>
// ```
//
// </details>

// %% [markdown]
// ---
// ➡ Si está bien formado, podremos validarlo más adelante.
// Continúa con **20 - Estructura del documento XML** 📄
