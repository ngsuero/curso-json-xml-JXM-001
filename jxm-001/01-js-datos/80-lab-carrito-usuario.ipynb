// %% [markdown]
// # Lab: Carrito y Usuario (checkout simulado)
//
// Objetivo: simular un pequeño checkout de un ecommerce usando los datos JSON locales.
//
// En cada paso tendras que **completar el codigo**. Debajo de cada bloque encontraras la solucion desplegable.

// %% [markdown]
// ## Paso 1: cargar catalogo y usuarios
//
// Tareas:
// - Cargar `products.json` en la variable `productos` usando `fetch()`.
// - Cargar `users.json` en la variable `usuarios`.
// - Mostrar ambos por consola.

// %%
// TODO: cargar products.json en la variable productos
// const productos = await fetch('...').then(r => r.json());

// TODO: cargar users.json en la variable usuarios
// const usuarios = ...

// TODO: mostrar por consola
// console.log(productos);
// console.log(usuarios);
const productos = await fetch('https://urban-space-system-wrp9wgrx4r9ph9wwv-5500.app.github.dev/jxm-001/data/products.json').then(r => r.json());
console.log(productos);

const usuarios = await fetch('https://urban-space-system-wrp9wgrx4r9ph9wwv-5500.app.github.dev/jxm-001/data/users.json').then(r => r.json());
console.log(usuarios);
// Out:
// [
//   {
//     id: 1,
//     nombre: "Raton inalambrico",
//     categoria: "ratones",
//     precio: 19.99,
//     stock: 25,
//     destacado: true
//   },
//   {
//     id: 2,
//     nombre: "Teclado mecanico",
//     categoria: "teclados",
//     precio: 79.9,
//     stock: 10,
//     destacado: true
//   },
//   {
//     id: 3,
//     nombre: "Pantalla 24 pulgadas",
//     categoria: "pantallas",
//     precio: 149,
//     stock: 5,
//     destacado: false
//   },
//   {
//     id: 4,
//     nombre: "Alfombrilla gaming",
//     categoria: "accesorios",
//     precio: 15.5,
//     stock: 40,
//     destacado: false
//   },
//   {
//     id: 5,
//     nombre: "Auriculares USB",
//     categoria: "audio",
//     precio: 39.9,
//     stock: 0,
//     destacado: true
//   }
// ]
// [
//   {
//     id: 1,
//     nombre: "Ana",
//     email: "ana@example.com",
//     vip: true,
//     pais: "ES"
//   },
//   {
//     id: 2,
//     nombre: "Luis",
// ...

// %% [markdown]
// <details><summary>Solucion Paso 1</summary>
//
// ```js
// const productos = await fetch('../data/products.json').then(r => r.json());
// const usuarios = await fetch('../data/users.json').then(r => r.json());
//
// console.log(productos);
// console.log(usuarios);
// ```
//
// </details>

// %% [markdown]
// ## Paso 2: seleccionar un usuario por email
//
// Tareas:
// - Elegir un email que exista en `usuarios`.
// - Buscar el usuario con `.find()`.
// - Guardarlo en la variable `usuario` y mostrarlo por consola.

// %%
// TODO: elige un email que exista en users.json
// const email = '...';

// TODO: busca el usuario con find
// const usuario = usuarios.find(...);

// TODO: muestra el usuario por consola
// console.log(usuario);
const miemail = 'ana@example.com';
const usuariomail = usuarios.find(usu => usu.email == miemail);
console.log(usuariomail);
// Out:
// {
//   id: 1,
//   nombre: "Ana",
//   email: "ana@example.com",
//   vip: true,
//   pais: "ES"
// }

// %% [markdown]
// <details><summary>Solucion Paso 2</summary>
//
// ```js
// const email = 'ana@example.com';
// const usuario = usuarios.find(u => u.email === email);
// console.log(usuario);
// ```
//
// </details>

// %% [markdown]
// ## Paso 3: crear el carrito
//
// Tarea:
// - Crear una variable `carrito` que sea un array vacio y mostrarlo.

// %%
// TODO: inicializar el carrito como array vacio
// const carrito = ...

// TODO: mostrar carrito
// console.log(carrito);

const carrito = [];
console.log(carrito);
// Out:
// []

// %% [markdown]
// <details><summary>Solucion Paso 3</summary>
//
// ```js
// const carrito = [];
// console.log(carrito);
// ```
//
// </details>

// %% [markdown]
// ## Paso 4: añadir productos al carrito
//
// Tareas:
// - Seleccionar un producto por `id` usando `.find()`.
// - Añadirlo al carrito con una cantidad, por ejemplo `{ producto, cantidad: 1 }`.
// - Repetir con otro producto distinto.

// %%
// TODO: seleccionar un producto por id
// const prod1 = productos.find(...);

// TODO: añadirlo al carrito con cantidad 1
// carrito.push({ producto: prod1, cantidad: 1 });

// TODO: seleccionar otro producto distinto
// const prod2 = productos.find(...);

// TODO: añadirlo al carrito con cantidad 2
// carrito.push({ producto: prod2, cantidad: 2 });

// TODO: mostrar carrito
// console.log(carrito);

const prod1 = productos.find(prod => prod.id == 1);
//console.log(prod1);
carrito.push({ producto: prod1, cantidad: 1 });
const prod2 = productos.find(prod => prod.id == 3);
carrito.push({ producto: prod2, cantidad: 1 });
console.log(carrito);
// Out:
// [
//   {
//     producto: {
//       id: 1,
//       nombre: "Raton inalambrico",
//       categoria: "ratones",
//       precio: 19.99,
//       stock: 25,
//       destacado: true
//     },
//     cantidad: 1
//   },
//   {
//     producto: {
//       id: 3,
//       nombre: "Pantalla 24 pulgadas",
//       categoria: "pantallas",
//       precio: 149,
//       stock: 5,
//       destacado: false
//     },
//     cantidad: 1
//   }
// ]

// %% [markdown]
// <details><summary>Solucion Paso 4</summary>
//
// ```js
// const prod1 = productos.find(p => p.id === 1);
// carrito.push({ producto: prod1, cantidad: 1 });
//
// const prod2 = productos.find(p => p.id === 2);
// carrito.push({ producto: prod2, cantidad: 2 });
//
// console.log(carrito);
// ```
//
// </details>

// %% [markdown]
// ## Paso 5: validar stock del carrito
//
// Tareas:
// - Recorrer el array `carrito` con `.forEach()`.
// - Comparar `cantidad` con `producto.stock`.
// - Si alguna cantidad supera el stock, mostrar un aviso y marcar `stockOK = false`.

// %%
// TODO: inicializar la bandera de stock
// let stockOK = true;

// TODO: recorrer el carrito y comparar cantidad con stock
// carrito.forEach(item => {
//   if ( ... ) {
//     console.warn('Sin stock suficiente para', item.producto.nombre);
//     stockOK = false;
//   }
// });

// TODO: mostrar resultado final
// console.log('Stock valido en todo el carrito:', stockOK);

// %% [markdown]
// <details><summary>Solucion Paso 5</summary>
//
// ```js
// let stockOK = true;
// carrito.forEach(item => {
//   if (item.cantidad > item.producto.stock) {
//     console.warn('Sin stock suficiente para', item.producto.nombre);
//     stockOK = false;
//   }
// });
// console.log('Stock valido en todo el carrito:', stockOK);
// ```
//
// </details>

// %% [markdown]
// ## Paso 6: calcular totales del carrito
//
// Tareas:
// - Calcular `totalItems` (numero de productos distintos).
// - Calcular `cantidadTotal` (suma de todas las cantidades).
// - Calcular `totalPrecio` (suma de precio * cantidad).

// %%
// TODO: numero de productos distintos
// const totalItems = ...;

// TODO: cantidad total de unidades (usa reduce)
// const cantidadTotal = carrito.reduce((acc, item) => ..., 0);

// TODO: precio total (usa reduce)
// const totalPrecio = carrito.reduce((acc, item) => ..., 0);

// TODO: mostrar resultado
// console.log({ totalItems, cantidadTotal, totalPrecio });

// %% [markdown]
// <details><summary>Solucion Paso 6</summary>
//
// ```js
// const totalItems = carrito.length;
// const cantidadTotal = carrito.reduce((acc, item) => acc + item.cantidad, 0);
// const totalPrecio = carrito.reduce(
//   (acc, item) => acc + item.producto.precio * item.cantidad,
//   0
// );
// console.log({ totalItems, cantidadTotal, totalPrecio });
// ```
//
// </details>

// %% [markdown]
// ## Paso 7: checklist final de la compra
//
// Tareas:
// - Comprobar que `usuario` existe.
// - Comprobar que `stockOK` es verdadero.
// - Comprobar que `totalPrecio` es mayor que 0.
// - Si todo es correcto, mostrar el mensaje `Checkout completado`.
// - Si algo falla, mostrar un aviso de error.

// %%
// TODO: comprobar condiciones y mostrar mensajes
// if (...) {
//   console.log('Checkout completado');
// } else {
//   console.warn('Hay errores antes de finalizar la compra');
// }

// %% [markdown]
// <details><summary>Solucion Paso 7</summary>
//
// ```js
// if (usuario && stockOK && totalPrecio > 0) {
//   console.log('Checkout completado');
// } else {
//   console.warn('Hay errores antes de finalizar la compra');
// }
// ```
//
// </details>

// %% [markdown]
// ---
// Has completado el lab del bloque 1.
//
// Cuando estes listo, continua con `02-json-web/10-json-sintaxis-estructuras.ipynb`.
