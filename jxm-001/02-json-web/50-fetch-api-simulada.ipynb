// %% [markdown]
// # Fetch API simulada (datos locales)
//
// En la web, los datos no están en el código: se **piden a un servidor**.
// Aquí simulamos una API usando `fetch()` sobre archivos JSON locales.
//
// Dataset: `../data/products.json`

// %% [markdown]
// ## Leer datos con fetch
// Si cargamos un JSON, obtenemos **una Promesa** que devuelve un objeto JS.

// %%
const productos = await fetch(new URL('https://organic-space-parakeet-6pv76qxwpp2x5pg-5500.app.github.dev/products.json'))
  .then(res => res.json());

console.log(productos);
// Out:
// [
//   {
//     id: 1,
//     nombre: "Raton inalambrico",
//     categoria: "ratones",
//     precio: 19.99,
//     stock: 25,
//     destacado: true
//   },
//   {
//     id: 2,
//     nombre: "Teclado mecanico",
//     categoria: "teclados",
//     precio: 79.9,
//     stock: 10,
//     destacado: true
//   },
//   {
//     id: 3,
//     nombre: "Pantalla 24 pulgadas",
//     categoria: "pantallas",
//     precio: 149,
//     stock: 5,
//     destacado: false
//   },
//   {
//     id: 4,
//     nombre: "Alfombrilla gaming",
//     categoria: "accesorios",
//     precio: 15.5,
//     stock: 40,
//     destacado: false
//   },
//   {
//     id: 5,
//     nombre: "Auriculares USB",
//     categoria: "audio",
//     precio: 39.9,
//     stock: 0,
//     destacado: true
//   }
// ]

// %% [markdown]
// ## Ver un producto
// Ejemplo: primer elemento del catálogo

// %%
console.log(productos[0]);
// Out:
// {
//   id: 1,
//   nombre: "Raton inalambrico",
//   categoria: "ratones",
//   precio: 19.99,
//   stock: 25,
//   destacado: true
// }

// %% [markdown]
// ## Filtrar datos recibidos
// Ejemplo: productos con stock > 0

// %%
const disponibles = productos.filter(p => p.stock > 0);
console.log(disponibles);
// Out:
// [
//   {
//     id: 1,
//     nombre: "Raton inalambrico",
//     categoria: "ratones",
//     precio: 19.99,
//     stock: 25,
//     destacado: true
//   },
//   {
//     id: 2,
//     nombre: "Teclado mecanico",
//     categoria: "teclados",
//     precio: 79.9,
//     stock: 10,
//     destacado: true
//   },
//   {
//     id: 3,
//     nombre: "Pantalla 24 pulgadas",
//     categoria: "pantallas",
//     precio: 149,
//     stock: 5,
//     destacado: false
//   },
//   {
//     id: 4,
//     nombre: "Alfombrilla gaming",
//     categoria: "accesorios",
//     precio: 15.5,
//     stock: 40,
//     destacado: false
//   }
// ]

// %% [markdown]
// ## Ordenar datos
// Ordenamos por precio ascendente

// %%
const ordenados = [...productos].sort((a, b) => a.precio - b.precio);
console.log(ordenados);
// Out:
// [
//   {
//     id: 4,
//     nombre: "Alfombrilla gaming",
//     categoria: "accesorios",
//     precio: 15.5,
//     stock: 40,
//     destacado: false
//   },
//   {
//     id: 1,
//     nombre: "Raton inalambrico",
//     categoria: "ratones",
//     precio: 19.99,
//     stock: 25,
//     destacado: true
//   },
//   {
//     id: 5,
//     nombre: "Auriculares USB",
//     categoria: "audio",
//     precio: 39.9,
//     stock: 0,
//     destacado: true
//   },
//   {
//     id: 2,
//     nombre: "Teclado mecanico",
//     categoria: "teclados",
//     precio: 79.9,
//     stock: 10,
//     destacado: true
//   },
//   {
//     id: 3,
//     nombre: "Pantalla 24 pulgadas",
//     categoria: "pantallas",
//     precio: 149,
//     stock: 5,
//     destacado: false
//   }
// ]

// %% [markdown]
// ## Crear una vista útil
// Transformar a `Nombre - Precio€` con `map()`

// %%
const vista = productos.map(p => `${p.nombre} - ${p.precio}€`);
console.log(vista);
// Out:
// [
//   "Raton inalambrico - 19.99€",
//   "Teclado mecanico - 79.9€",
//   "Pantalla 24 pulgadas - 149€",
//   "Alfombrilla gaming - 15.5€",
//   "Auriculares USB - 39.9€"
// ]

// %% [markdown]
// ### 🧩 Ejercicio
// Obtén solo los productos **destacados** (`destacado: true`) usando `filter()`.
//
// Imprime la lista resultante.

// %%
// Tu codigo aquí...
// console.log(destacados);

// %% [markdown]
// <details><summary>Solución</summary>
//
// ```js
// const destacados = productos.filter(p => p.destacado);
// console.log(destacados);
// ```
// </details>

// %% [markdown]
// ---
// Ahora ya sabes consumir datos como una API 🚀
//
// ➡️ Siguiente: **60-render-html-notebook.ipynb**
// Mostraremos el catálogo con elementos HTML 😎
