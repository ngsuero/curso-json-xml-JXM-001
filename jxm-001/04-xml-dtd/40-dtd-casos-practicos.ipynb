// %% [markdown]
// # 📌 Casos prácticos de DTD
//
// Vamos a ver **patrones comunes** al definir DTD en XML real:
//
// ✔ Reglas de negocio sobre elementos
// ✔ Elementos opcionales
// ✔ Reglas de repetición + orden
// ✔ Atributos con opciones restringidas

// %% [markdown]
// ## 1️⃣ Opcionalidad en elementos
//
// 📌 `?` → 0 o 1 vez
//
// Ejemplo: un producto puede o no tener `descripcion`:

// %%
<!ELEMENT producto (nombre, precio, descripcion?)>
<!ELEMENT descripcion (#PCDATA)>

// %% [markdown]
// ### 🧩 Ejercicio
// Modifica para que **descripcion sea obligatoria**.

// %%
// Tu cambio aqui...

// %% [markdown]
// <details><summary>Solución</summary>
//
// ```dtd
// <!ELEMENT producto (nombre, precio, descripcion)>
// ```
// </details>

// %% [markdown]
// ## 2️⃣ Repetición de elementos
//
// 📌 `+` → 1 o más
//
// Ejemplo: un catálogo debe tener productos:

// %%
<!ELEMENT catalogo (producto+)>

// %% [markdown]
// ### 🧩 Ejercicio
// Cambia la regla para permitir catálogos **vacíos**.

// %%
// Tu solución aquí...

// %% [markdown]
// <details><summary>Solución</summary>
//
// ```dtd
// <!ELEMENT catalogo (producto*)>
// ```
// </details>

// %% [markdown]
// ## 3️⃣ Orden estricto de contenido
//
// XML **no permite cambiar el orden** si lo define la DTD:

// %%
<!ELEMENT producto (nombre, precio)>

// %% [markdown]
// 🔴 Esto sería **inválido**:
//
// ```xml
// <producto>
//   <precio>80</precio>  <!-- ❌ mal orden -->
//   <nombre>Teclado</nombre>
// </producto>
// ```

// %% [markdown]
// ## 4️⃣ Atributos restringidos
//
// Podemos forzar un atributo a tomar **solo ciertos valores**:

// %%
<!ATTLIST producto estado (nuevo | usado) #REQUIRED>

// %% [markdown]
// ### 🧩 Ejercicio
// Haz que `estado` sea opcional y por defecto `nuevo`.

// %%
// Tu DTD aqui...

// %% [markdown]
// <details><summary>Solución</summary>
//
// ```dtd
// <!ATTLIST producto estado (nuevo | usado) "nuevo">
// ```
// </details>

// %% [markdown]
// ---
// 🎯 En el próximo notebook:
// **80-lab-calidad-dtd.ipynb**
// Aplicaremos todos estos casos en un catálogo real 🚀
